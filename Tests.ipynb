# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import os
import glob
import numpy as np
from skimage.transform import resize
from skimage.io import imsave
from skimage.io import imread


from keras.models import Model
from keras.layers import Input, concatenate, Conv3D, MaxPooling3D, Conv3DTranspose, AveragePooling3D, ZeroPadding3D
from keras.optimizers import RMSprop, Adam, SGD
from keras.callbacks import ModelCheckpoint, CSVLogger
from keras import backend as K
from keras.regularizers import l2
from keras.utils import plot_model
# Out:
# Using TensorFlow backend.

# %%
def deform(array, factor, axis):
    stretched = np.repeat(array, np.ceil(factor), axis=axis)
    indices = np.linspace(0, stretched.shape[axis] - 1, int(array.shape[axis] * factor))
    indices = np.rint(indices).astype(int)
    return np.take(stretched, indices, axis=axis)

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
K.set_image_data_format('channels_last')

data_path = './'
project_name = '3D-Unet'
img_depth = 32
img_rows = 64
img_cols = 64
smooth = 1.

# %%
def get_unet():
    inputs = Input((img_depth, img_rows, img_cols, 1))
    conv1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling3D(pool_size=(2, 2, 2))(conv1)

    conv2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling3D(pool_size=(2, 2, 2))(conv2)

    conv3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling3D(pool_size=(2, 2, 2))(conv3)

    conv4 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling3D(pool_size=(2, 2, 2))(conv4)

    conv5 = Conv3D(512, (3, 3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv3D(512, (3, 3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv3DTranspose(256, (2, 2, 2), strides=(2, 2, 2), padding='same')(conv5), conv4], axis=4)
    conv6 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(conv6), conv3], axis=4)
    conv7 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(conv7), conv2], axis=4)
    conv8 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(conv8), conv1], axis=4)
    conv9 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv3D(1, (1, 1, 1), activation='sigmoid')(conv9)


    model = Model(inputs=[inputs], outputs=[conv10])

    model.summary()
    #plot_model(model, to_file='model.png')

    model.compile(optimizer=Adam(lr=2*1e-5), loss=dice_coef_loss, metrics=[dice_coef])

    return model

# %%
def train():
    print('-'*30)
    print('Loading and preprocessing train data...')
    print('-'*30)
    
    a = np.load('input_1.npz')['arr_0'][0]
    b = np.load('terminal_mask_1.npz')['arr_0'][0]
    
    a = np.transpose(a)
    b = np.transpose(b)
    
    a = deform(a, img_depth/a.shape[0], axis=0)
    a = deform(a, img_rows/a.shape[1], axis=1)
    a = deform(a, img_cols/a.shape[2], axis=2)
    
    b = deform(b, img_depth/b.shape[0], axis=0)
    b = deform(b, img_rows/b.shape[1], axis=1)
    b = deform(b, img_cols/b.shape[2], axis=2)

    A = np.array([a,a,a,a,a,a,a,a,a,a])
    B = np.array([b,b,b,b,b,b,b,b,b,b])
    
    imgs_train = np.expand_dims(A, axis=4)
    imgs_mask_train = np.expand_dims(B, axis=4)
    
    imgs_train = imgs_train.astype('float32')
    imgs_mask_train = imgs_mask_train.astype('float32')
    
    print(imgs_mask_train.shape)
    print(imgs_train.shape)

    print('-'*30)
    print('Creating and compiling model...')
    print('-'*30)
    model = get_unet()
    weight_dir = 'weights'
    if not os.path.exists(weight_dir):
        os.mkdir(weight_dir)
    model_checkpoint = ModelCheckpoint(os.path.join(weight_dir, project_name + '.h5'), monitor='val_loss', save_best_only=True)

    log_dir = 'logs'
    if not os.path.exists(log_dir):
        os.mkdir(log_dir)
    csv_logger = CSVLogger(os.path.join(log_dir,  project_name + '.txt'), separator=',', append=False)

    print('-'*30)
    print('Fitting model...')
    print('-'*30)

    model.fit(imgs_train, imgs_mask_train, batch_size=2, epochs=200, verbose=1, shuffle=True, validation_split=0.20, callbacks=[model_checkpoint, csv_logger])

    print('-'*30)
    print('Training finished')
    print('-'*30)
    
    A = np.array([a])
    imgs_train = np.expand_dims(A, axis=4)
    imgs_test = imgs_train.astype('float32')
    
    imgs_mask_test = model.predict(imgs_test, batch_size=1, verbose=1)

    npy_mask_dir = 'test_mask_npy'
    if not os.path.exists(npy_mask_dir):
        os.mkdir(npy_mask_dir)

    np.save(os.path.join(npy_mask_dir, project_name + '_mask.npy'), imgs_mask_test)

# %%
train()
# Out:
# ------------------------------
# Loading and preprocessing train data...
# ------------------------------
# (10, 32, 64, 64, 1)
# (10, 32, 64, 64, 1)
# ------------------------------
# Creating and compiling model...
# ------------------------------
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 64, 64, 1 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 32, 64, 64, 3 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 32, 64, 64, 3 27680       conv3d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 16, 32, 32, 3 0           conv3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 16, 32, 32, 6 55360       max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 16, 32, 32, 6 110656      conv3d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 8, 16, 16, 64 0           conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 8, 16, 16, 12 221312      max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 8, 16, 16, 12 442496      conv3d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 4, 8, 8, 128) 0           conv3d_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 4, 8, 8, 256) 884992      max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 4, 8, 8, 256) 1769728     conv3d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 2, 4, 4, 256) 0           conv3d_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 2, 4, 4, 512) 3539456     max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 2, 4, 4, 512) 7078400     conv3d_9[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTrans (None, 4, 8, 8, 256) 1048832     conv3d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 8, 8, 512) 0           conv3d_transpose_1[0][0]
#                                                                  conv3d_8[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 4, 8, 8, 256) 3539200     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 4, 8, 8, 256) 1769728     conv3d_11[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_2 (Conv3DTrans (None, 8, 16, 16, 12 262272      conv3d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 16, 16, 25 0           conv3d_transpose_2[0][0]
#                                                                  conv3d_6[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 8, 16, 16, 12 884864      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 8, 16, 16, 12 442496      conv3d_13[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (None, 16, 32, 32, 6 65600       conv3d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 32, 32, 1 0           conv3d_transpose_3[0][0]
#                                                                  conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 16, 32, 32, 6 221248      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 16, 32, 32, 6 110656      conv3d_15[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_4 (Conv3DTrans (None, 32, 64, 64, 3 16416       conv3d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 64, 64, 6 0           conv3d_transpose_4[0][0]
#                                                                  conv3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 32, 64, 64, 3 55328       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 32, 64, 64, 3 27680       conv3d_17[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 32, 64, 64, 1 33          conv3d_18[0][0]
# ==================================================================================================
# Total params: 22,575,329
# Trainable params: 22,575,329
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ------------------------------
# Fitting model...
# ------------------------------
# Train on 8 samples, validate on 2 samples
# Epoch 1/200
# 8/8 [==============================] - 3s 360ms/step - loss: -0.0024 - dice_coef: 0.0024 - val_loss: -0.0038 - val_dice_coef: 0.0038
# Epoch 2/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.0049 - dice_coef: 0.0049 - val_loss: -0.0069 - val_dice_coef: 0.0069
# Epoch 3/200
# 8/8 [==============================] - 0s 57ms/step - loss: -0.0089 - dice_coef: 0.0089 - val_loss: -0.0132 - val_dice_coef: 0.0132
# Epoch 4/200
# 8/8 [==============================] - 0s 57ms/step - loss: -0.0178 - dice_coef: 0.0178 - val_loss: -0.0280 - val_dice_coef: 0.0280
# Epoch 5/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.0379 - dice_coef: 0.0379 - val_loss: -0.0585 - val_dice_coef: 0.0585
# Epoch 6/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.0775 - dice_coef: 0.0775 - val_loss: -0.1159 - val_dice_coef: 0.1159
# Epoch 7/200
# 8/8 [==============================] - 0s 57ms/step - loss: -0.1494 - dice_coef: 0.1494 - val_loss: -0.2133 - val_dice_coef: 0.2133
# Epoch 8/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.2612 - dice_coef: 0.2612 - val_loss: -0.3521 - val_dice_coef: 0.3521
# Epoch 9/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.4124 - dice_coef: 0.4124 - val_loss: -0.5061 - val_dice_coef: 0.5061
# Epoch 10/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.5536 - dice_coef: 0.5536 - val_loss: -0.6294 - val_dice_coef: 0.6294
# Epoch 11/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.6632 - dice_coef: 0.6632 - val_loss: -0.7090 - val_dice_coef: 0.7090
# Epoch 12/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.7315 - dice_coef: 0.7315 - val_loss: -0.7542 - val_dice_coef: 0.7542
# Epoch 13/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.7579 - dice_coef: 0.7579 - val_loss: -0.7626 - val_dice_coef: 0.7626
# Epoch 14/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.7674 - dice_coef: 0.7674 - val_loss: -0.7868 - val_dice_coef: 0.7868
# Epoch 15/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.7953 - dice_coef: 0.7953 - val_loss: -0.8007 - val_dice_coef: 0.8007
# Epoch 16/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8028 - dice_coef: 0.8028 - val_loss: -0.8044 - val_dice_coef: 0.8044
# Epoch 17/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8045 - dice_coef: 0.8045 - val_loss: -0.8049 - val_dice_coef: 0.8049
# Epoch 18/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8051 - dice_coef: 0.8051 - val_loss: -0.8056 - val_dice_coef: 0.8056
# Epoch 19/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8058 - dice_coef: 0.8058 - val_loss: -0.8061 - val_dice_coef: 0.8061
# Epoch 20/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8062 - dice_coef: 0.8062 - val_loss: -0.8065 - val_dice_coef: 0.8065
# Epoch 21/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8083 - dice_coef: 0.8083 - val_loss: -0.8167 - val_dice_coef: 0.8167
# Epoch 22/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8166 - dice_coef: 0.8166 - val_loss: -0.8160 - val_dice_coef: 0.8160
# Epoch 23/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8163 - dice_coef: 0.8163 - val_loss: -0.8167 - val_dice_coef: 0.8167
# Epoch 24/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8168 - dice_coef: 0.8168 - val_loss: -0.8169 - val_dice_coef: 0.8169
# Epoch 25/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8169 - dice_coef: 0.8169 - val_loss: -0.8170 - val_dice_coef: 0.8170
# Epoch 26/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8170 - dice_coef: 0.8170 - val_loss: -0.8171 - val_dice_coef: 0.8171
# Epoch 27/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8171 - dice_coef: 0.8171 - val_loss: -0.8172 - val_dice_coef: 0.8172
# Epoch 28/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8172 - dice_coef: 0.8172 - val_loss: -0.8173 - val_dice_coef: 0.8173
# Epoch 29/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8173 - dice_coef: 0.8173 - val_loss: -0.8173 - val_dice_coef: 0.8173
# Epoch 30/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8174 - dice_coef: 0.8174 - val_loss: -0.8174 - val_dice_coef: 0.8174
# Epoch 31/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8174 - dice_coef: 0.8174 - val_loss: -0.8175 - val_dice_coef: 0.8175
# Epoch 32/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8175 - dice_coef: 0.8175 - val_loss: -0.8175 - val_dice_coef: 0.8175
# Epoch 33/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8175 - dice_coef: 0.8175 - val_loss: -0.8175 - val_dice_coef: 0.8175
# Epoch 34/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8176 - dice_coef: 0.8176 - val_loss: -0.8176 - val_dice_coef: 0.8176
# Epoch 35/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8176 - dice_coef: 0.8176 - val_loss: -0.8176 - val_dice_coef: 0.8176
# Epoch 36/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8176 - dice_coef: 0.8176 - val_loss: -0.8176 - val_dice_coef: 0.8176
# Epoch 37/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8177 - dice_coef: 0.8177 - val_loss: -0.8177 - val_dice_coef: 0.8177
# Epoch 38/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8177 - dice_coef: 0.8177 - val_loss: -0.8177 - val_dice_coef: 0.8177
# Epoch 39/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8177 - dice_coef: 0.8177 - val_loss: -0.8177 - val_dice_coef: 0.8177
# Epoch 40/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8177 - dice_coef: 0.8177 - val_loss: -0.8177 - val_dice_coef: 0.8177
# Epoch 41/200
# 8/8 [==============================] - 0s 57ms/step - loss: -0.8177 - dice_coef: 0.8177 - val_loss: -0.8178 - val_dice_coef: 0.8178
# Epoch 42/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8178 - dice_coef: 0.8178 - val_loss: -0.8178 - val_dice_coef: 0.8178
# Epoch 43/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8178 - dice_coef: 0.8178 - val_loss: -0.8178 - val_dice_coef: 0.8178
# Epoch 44/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8178 - dice_coef: 0.8178 - val_loss: -0.8178 - val_dice_coef: 0.8178
# Epoch 45/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8178 - dice_coef: 0.8178 - val_loss: -0.8178 - val_dice_coef: 0.8178
# Epoch 46/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8178 - dice_coef: 0.8178 - val_loss: -0.8178 - val_dice_coef: 0.8178
# Epoch 47/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8178 - dice_coef: 0.8178 - val_loss: -0.8178 - val_dice_coef: 0.8178
# Epoch 48/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8179 - val_dice_coef: 0.8179
# Epoch 49/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8179 - val_dice_coef: 0.8179
# Epoch 50/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8179 - val_dice_coef: 0.8179
# Epoch 51/200
# 8/8 [==============================] - 0s 57ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8179 - val_dice_coef: 0.8179
# Epoch 52/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8179 - val_dice_coef: 0.8179
# Epoch 53/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8179 - val_dice_coef: 0.8179
# Epoch 54/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8179 - val_dice_coef: 0.8179
# Epoch 55/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8179 - val_dice_coef: 0.8179
# Epoch 56/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8179 - val_dice_coef: 0.8179
# Epoch 57/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8179 - val_dice_coef: 0.8179
# Epoch 58/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 59/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 60/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 61/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 62/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 63/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 64/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 65/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 66/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 67/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 68/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 69/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 70/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 71/200
# 8/8 [==============================] - 0s 57ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 72/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 73/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 74/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 75/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 76/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 77/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 78/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8180 - dice_coef: 0.8180 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 79/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 80/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 81/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 82/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 83/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 84/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 85/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 86/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 87/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 88/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 89/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 90/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 91/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 92/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 93/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 94/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 95/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 96/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 97/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 98/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 99/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 100/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 101/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 102/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 103/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 104/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 105/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 106/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 107/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 108/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 109/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 110/200
# 8/8 [==============================] - 0s 60ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 111/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 112/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 113/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 114/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8181 - dice_coef: 0.8181 - val_loss: -0.8181 - val_dice_coef: 0.8181
# Epoch 115/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8208 - dice_coef: 0.8208 - val_loss: -0.8195 - val_dice_coef: 0.8195
# Epoch 116/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8220 - dice_coef: 0.8220 - val_loss: -0.8279 - val_dice_coef: 0.8279
# Epoch 117/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8279 - dice_coef: 0.8279 - val_loss: -0.8274 - val_dice_coef: 0.8274
# Epoch 118/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8275 - dice_coef: 0.8275 - val_loss: -0.8279 - val_dice_coef: 0.8279
# Epoch 119/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8280 - dice_coef: 0.8280 - val_loss: -0.8280 - val_dice_coef: 0.8280
# Epoch 120/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8280 - dice_coef: 0.8280 - val_loss: -0.8281 - val_dice_coef: 0.8281
# Epoch 121/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8281 - dice_coef: 0.8281 - val_loss: -0.8281 - val_dice_coef: 0.8281
# Epoch 122/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8281 - dice_coef: 0.8281 - val_loss: -0.8281 - val_dice_coef: 0.8281
# Epoch 123/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8281 - dice_coef: 0.8281 - val_loss: -0.8281 - val_dice_coef: 0.8281
# Epoch 124/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8281 - dice_coef: 0.8281 - val_loss: -0.8281 - val_dice_coef: 0.8281
# Epoch 125/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8281 - dice_coef: 0.8281 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 126/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 127/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 128/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 129/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 130/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 131/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 132/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 133/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 134/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 135/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 136/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 137/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 138/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 139/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 140/200
# 8/8 [==============================] - 0s 60ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 141/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 142/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 143/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 144/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 145/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 146/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 147/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 148/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 149/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8282 - dice_coef: 0.8282 - val_loss: -0.8282 - val_dice_coef: 0.8282
# Epoch 150/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8282 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 151/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 152/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 153/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 154/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 155/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 156/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 157/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 158/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 159/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 160/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 161/200
# 8/8 [==============================] - 0s 60ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 162/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 163/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 164/200
# 8/8 [==============================] - 0s 57ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 165/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 166/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 167/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 168/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 169/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 170/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 171/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 172/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 173/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 174/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 175/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 176/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 177/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 178/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 179/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 180/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 181/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 182/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 183/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 184/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 185/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 186/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 187/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 188/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 189/200
# 8/8 [==============================] - 0s 60ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 190/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 191/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 192/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 193/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 194/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 195/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 196/200
# 8/8 [==============================] - 0s 58ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 197/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 198/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 199/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# Epoch 200/200
# 8/8 [==============================] - 0s 59ms/step - loss: -0.8283 - dice_coef: 0.8283 - val_loss: -0.8283 - val_dice_coef: 0.8283
# ------------------------------
# Training finished
# ------------------------------
# 1/1 [==============================] - 0s 274ms/step
